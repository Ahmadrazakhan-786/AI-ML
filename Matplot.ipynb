# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [1,2,3,4,5]
y = [2,6,8,10,12]

plt.plot(x,y) # basic line graph
plt.show() # graph display karega
plt.xlabel("X Axis label")
plt.ylabel("Y Axis label")
plt.show()
plt.title("Simple line plot")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.bar(x,y, color = "green")
plt.title("Bar graph example")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show() # Bar graph example

# %%
import matplotlib.pyplot as plt
x = [3,5,7,9]
y= [1,2,3,4]
plt.scatter(x,y, color="red", marker = "*")
plt.title("Scatter Box")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
import matplotlib.pyplot as plt
ages =  [22, 25, 27, 22, 29, 34, 40, 22, 36, 28, 30, 25, 40, 42, 45]
plt.hist(hist,ages,bins=5, color = "skyblue", edgecolor="black")
plt.title("Age Distribution")
plt.xlabel("Age Groups")
plt.ylabel("frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import matplotlib.pyplot as plt
#       2 ages =  [22, 25, 27, 22, 29, 34, 40, 22, 36, 28, 30, 25, 40, 42, 45]
# ----> 3 plt.hist(hist,ages,bins=5, color = "skyblue", edgecolor="black")
#       4 plt.title("Age Distribution")
#       5 plt.xlabel("Age Groups")
#
# NameError: name 'hist' is not defined
